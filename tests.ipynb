# %%
import pickle as pkl
from pprint import pprint

# %%
with open("../nvme/en_topics/savepoints/page_topics_2999202_3020000.pkl", 'rb') as f:
    test_page_topics = pkl.load(f)
pprint(list(test_page_topics.items())[:10])
# Out:
# [(28692689,
#   {1: ['Heavy metal music', 'Music'],
#    2: ['21st century', 'Heavy metal music', 'Music', 'Arts'],
#    3: ['Arts', 'Music', '2010s fads', 'Trends', 'Heavy metal'],
#    4: ['Works', 'Decade', '21st-century fads and trends', 'Arts', 'Fads']}),
#  (28692719,
#   {1: ['Disambiguation pages'],
#    2: ['Wikipedia disambiguation'],
#    3: ['Wikipedia content administration'],
#    4: ['Wikipedia administration']}),
#  (28692739,
#   {1: ["Wright state raiders men's basketball seasons",
#        'Sports',
#        'Ohio',
#        "2010–11 horizon league men's basketball season"],
#    2: ['State',
#        'American sports',
#        'Ohio',
#        "Horizon league men's basketball seasons",
#        'Wright state raiders seasons'],
#    3: ['Wright state raiders basketball',
#        "College men's basketball conference seasons in the united states",
#        'School',
#        'United states',
#        'Ohio'],
#    4: ['2010–11 in american basketball',
# ...
